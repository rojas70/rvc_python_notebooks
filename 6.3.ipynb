# %%
# Works best with jupyter-notebook

# %%
# %matplotlib notebook 
#%matplotlib widget 
# https://ipython.readthedocs.io/en/stable/interactive/magics.html
import numpy as np
import roboticstoolbox as rtb
import spatialmath.base as sm
import matplotlib.pyplot as plt
import math
from spatialmath import *
from spatialmath.base import *
from collections import namedtuple
from roboticstoolbox import *
np.set_printoptions(linewidth=100, formatter={'float': lambda x: f"{x:8.4g}" if abs(x) > 1e-10 else f"{0:8.4g}"})

# %% [markdown]
# ##### Lecture 7.7

# %% [markdown]
# Numerical inverse kinematics

# %%
#Load a model of a 2-link planar robot
robot = rtb.models.DH.Planar2()
print(robot)
robot.plot(robot.qz)
# Out:
# ┏━━━━┳━━━━━┳━━━━┳━━━━━━┓
# ┃θⱼ  ┃ dⱼ  ┃ aⱼ ┃  ⍺ⱼ  ┃
# ┣━━━━╋━━━━━╋━━━━╋━━━━━━┫
# ┃ q1 ┃ 0.0 ┃  1 ┃ 0.0° ┃
# ┃ q2 ┃ 0.0 ┃  1 ┃ 0.0° ┃
# ┗━━━━┻━━━━━┻━━━━┻━━━━━━┛
#
# ┌─────┬──────┬──────┐
# │name │ q0   │ q1   │
# ├─────┼──────┼──────┤
# │  qz │  0°  │  0°  │
# │  q1 │  0°  │  90° │
# │  q2 │  90° │ -90° │
# └─────┴──────┴──────┘
# <img src="data:image/png;base64,..." width="640">

# %%
#Define a desired pose:
q = robot.ikine_a(T, "run")
q
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-3aabbc4dac02> in <module>
#       1 #Define a desired pose:
# ----> 2 q = robot.ikine_a(T, "run")
#       3 q
#
# AttributeError: 'Planar2' object has no attribute 'ikine_a'

# %%
q = robot.ikine_a(T, "run")
q

# %%
#Calculate the inverse kinematics beginning with zero angles 
#and specifying that only the x and y coordinates are critically important 
#(i.e. we don't care about the z coordinate nor the orientation) and then plot the configuration:
(q, failed, reason) = robot.ikine(T)
q
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-7aa1d06fdfc2> in <module>
#       2 #and specifying that only the x and y coordinates are critically important
#       3 #(i.e. we don't care about the z coordinate nor the orientation) and then plot the configuration:
# ----> 4 (q, failed, reason) = robot.ikine(T)
#       5 q
#
# ~\anaconda3\lib\site-packages\roboticstoolbox\robot\Robot.py in ikine(self, T, ilimit, rlimit, tol, Y, Ymin, mask, q0, search, slimit, transpose)
#     763
#     764         if not self.n >= np.sum(mask):
# --> 765             raise ValueError('Number of robot DOF must be >= the same number '
#     766                              'of 1s in the mask matrix')
#     767         W = np.diag(mask)
#
# ValueError: Number of robot DOF must be >= the same number of 1s in the mask matrix

# %%
failed
# Out:
# True

# %% [markdown]
# indicating, in this case, that there is no failure. The joint coordinates are

# %%
q
# Out:
# array([  0.4926,   -1.315,  -0.4957,   0.1534,    1.516,  -0.5691])

# %%
q = robot.ikine_a(T, "run")
q
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-ef5c8b314ab1> in <module>
# ----> 1 q = robot.ikine_a(T, "run")
#       2 q
#
# C:\ProgramData\Anaconda3\lib\site-packages\roboticstoolbox\models\DH\Puma560.py in ikine_a(self, T, config)
#     263
#     264     def ikine_a(self, T, config="lun"):
# --> 265         return self.ikine_6s(T, config, self._ikine)
#     266
#     267 if __name__ == '__main__':    # pragma nocover
#
# C:\ProgramData\Anaconda3\lib\site-packages\roboticstoolbox\robot\DHRobot.py in ikine_6s(self, T, config, _ikfunc)
#    1865         # set, skip the operation.  Nicer for symbolics
#    1866         if self._base is not None:
# -> 1867             T = self.base.inv() * T
#    1868         if self._tool is not None:
#    1869             T = self.tool.inv() * T
#
# ...
