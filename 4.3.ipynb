# %%
# Works best with jupyter-notebook

# %%
# %matplotlib notebook 
#%matplotlib widget 
# https://ipython.readthedocs.io/en/stable/interactive/magics.html
import numpy as np
import math
from spatialmath import *
from spatialmath.base import *
from roboticstoolbox import *
from collections import namedtuple
import roboticstoolbox.tools.trajectory as tr
import matplotlib.pyplot as plt

np.set_printoptions(linewidth=100, formatter={'float': lambda x: f"{x:8.4g}" if abs(x) > 1e-10 else f"{0:8.4g}"})

# %% [markdown]
# # Lecture 4.3

# %% [markdown]
# 1D trapezoidal trajectories

# %%
#Create a trapezoidal trajectory using the toolbox function lspb(),
#passing in the initial position of 0 and a final position of 1 over 50 timesteps
#The function will return the vector s,sd, and sdd
data=tr.lspb(0, 1, 50)
t=data.x
s=data.y
sd=data.yd
sdd=data.ydd

# %%
#plot;
fig1=plt.figure(1);
#1
sfig1=fig1.add_subplot(3,1,1);
plt.plot(t,s);
#2
sfig2=fig1.add_subplot(3,1,2);
plt.plot(t,sd);
#3
sfig3=fig1.add_subplot(3,1,3);
plt.plot(t,sdd);

#print(s,sd,sdd)
# Out:
# <img src="data:image/png;base64,..." width="639.9166666666667">

# %%
#Changing the value of the final position from 1 to -1 gives
data=tr.lspb(0, -1, 50)
t=data.x
s=data.y
sd=data.yd
sdd=data.ydd
#plot
fig2=plt.figure(2);
#1
sfig1=fig2.add_subplot(3,1,1);
plt.plot(t,s);
#2
sfig2=fig2.add_subplot(3,1,2);
plt.plot(t,sd);
#3
sfig3=fig2.add_subplot(3,1,3);
plt.plot(t,sdd);
# Out:
# <img src="data:image/png;base64,..." width="639.9166666666667">

# %%
#The top velocity of the linear segment can be explicitly specified by passing in additional argument, in this case 0.025:
data=tr.lspb(0, 1, 50, 0.025)
t=data.x
s=data.y
sd=data.yd
sdd=data.ydd

# %%
#plot
fig3=plt.figure(3);
#1
sfig1=fig3.add_subplot(3,1,1);
plt.plot(t,s);
#2
sfig2=fig3.add_subplot(3,1,2);
plt.plot(t,sd);
#3
sfig3=fig3.add_subplot(3,1,3);
plt.plot(t,sdd);
# Out:
# <img src="data:image/png;base64,..." width="639.9166666666667">

# %%
#Increasing the velocity of the linear segment to 0.035 gives:
data=tr.lspb(0, 1, 50, 0.035)
t=data.x
s=data.y
sd=data.yd
sdd=data.ydd

#plot
fig4=plt.figure(4)
#1
sfig1=fig4.add_subplot(3,1,1)
plt.plot(t,s)
#2
sfig2=fig4.add_subplot(3,1,2)
plt.plot(t,sd)
#3
sfig3=fig4.add_subplot(3,1,3)
plt.plot(t,sdd)
# Out:
# <img src="data:image/png;base64,..." width="639.9166666666667">

# %%
#Reducing the velocity of the linear segment to 0.2 returns an error as the velocity specified is too small
#it is not possible to compute a trapezoidal profile with that value of velocity for the linear segment.
data=tr.lspb(0, 1, 50, 0.02)
# Out:
# -----------------------------------------------------------------------
# ValueError                            Traceback (most recent call last)
# <ipython-input-11-afad797faf95> in <module>
#       1 #Reducing the velocity of the linear segment to 0.2 returns an error as the velocity specified is too small
#       2 #it is not possible to compute a trapezoidal profile with that value of velocity for the linear segment.
# ----> 3 data=tr.lspb(0, 1, 50, 0.02)
#
# /media/juan/sdd/python/toolbox/robotics-toolbox-python/roboticstoolbox/tools/trajectory.py in lspb(q0, qf, t, V)
#     170         V = abs(V) * np.sign(qf - q0)
#     171         if abs(V) < (abs(qf - q0) / tf):
# --> 172             raise ValueError('V too small')
#     173         elif abs(V) > (2 * abs(qf-q0) / tf):
#     174             raise ValueError('V too big')
#
# ValueError: V too small
